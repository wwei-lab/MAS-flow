# %%
library(igraph)
library(dplyr)
library(parallel)
library(stringr)

# %%
tsv = read.table("../data/T47_MAS_SEQ_20240104/edlibR/adapter.list.T47.mismatch2.df.tsv")

# %%
colnames(tsv) = c("start","end","width","type","fqname")

# %%
plot_adapter_num = function(df,title){
    set.seed(43)
    palette <- distinctColorPalette(450)
    adapter.list.edlibR.mismatch.count = df %>% group_by(fqname) %>% summarise(adapter_count = n())
    df2 = df %>% group_by(fqname) %>%
        summarise(adapter_chain = paste(type,collapse = ","))
    df2$classification = unlist(lapply(df2$adapter_chain,classify_read))
    adapter.list.edlibR.mismatch.count.table = data.frame(table(adapter.list.edlibR.mismatch.count$adapter_count,df2$classification))
    colnames(adapter.list.edlibR.mismatch.count.table) = c("adapter_count","adapter_classification","count")
    adapter.list.edlibR.mismatch.count.table = adapter.list.edlibR.mismatch.count.table %>% arrange(adapter_classification)
    names(palette) = all.classification
    ggplot(adapter.list.edlibR.mismatch.count.table, aes(fill=adapter_classification, y=count, x=adapter_count)) + 
        geom_bar(position="stack", stat="identity") + scale_fill_manual(values = palette) +
    theme_bw() + guides(fill=guide_legend(ncol=2)) + ggtitle(title)
}

adapter_num = function(df){
    adapter.list.edlibR.mismatch.count = df %>% group_by(fqname) %>% summarise(adapter_count = n())
    df2 = df %>% group_by(fqname) %>%
        summarise(adapter_chain = paste(type,collapse = ","))
    unlist(mclapply(df2$adapter_chain,classify_read,mc.cores = 80))
}

order_suffix = function(x){
    paste(sort(str_split(x,"-")[[1]]),sep = "-")
}

classify_read = function(adapter_chain,adapters_graph = adapter_graph){
    adapters = str_split(adapter_chain,pattern = ",")[[1]]
    all.forward = all(!grepl(adapters,pattern = "*rc$"))
    all.reverse = all(grepl(adapters,pattern = "*rc$"))
    #This no.rc means that the read has no palindrome sequence.
    rc_mix = !(all.forward | all.reverse)
    forward.index = which(!grepl(adapters,pattern = "*rc$"))
    reverse.index = grep(adapters,pattern = "*rc$")

    rc_mix = ifelse(rc_mix,ifelse(all(diff(forward.index)==1) & all(diff(reverse.index)==1),"RC-successive","RC-mosaic"),"No-RC")
    forward.adapters = adapters[forward.index]
    reverse.adapters = adapters[reverse.index]
    
    if((length(forward.adapters)+length(reverse.adapters))>1){
        if(length(forward.adapters) == 1 & length(reverse.adapters) == 1){
            suffix = "Singleton-Singleton"
        }else if(length(forward.adapters) <= 1){
            reverse.adapters = data.frame(from = reverse.adapters[1:(length(reverse.adapters)-1)],
                                      to = reverse.adapters[2:length(reverse.adapters)])
            reverse.dist = apply(reverse.adapters,1,function(reverse.adapter){
                test_paths(adapters_graph,reverse.adapter[1],reverse.adapter[2])
            })
            reverse.adapter_sequence = ifelse(any(is.infinite(reverse.dist)),"Wrong direction",ifelse(all(reverse.dist==1),"Successive","Jump"))
            forward.adapter_sequence = ifelse(length(forward.adapters)==0,"NA","Singleton")
            suffix = paste(forward.adapter_sequence,reverse.adapter_sequence,sep = "-")
            suffix = order_suffix(suffix)
        }else if(length(reverse.adapters) <= 1){
            forward.adapters = data.frame(from = forward.adapters[1:(length(forward.adapters)-1)],
                                  to = forward.adapters[2:length(forward.adapters)])
            forward.dist = apply(forward.adapters,1,function(forward.adapter){
                test_paths(adapters_graph,forward.adapter[1],forward.adapter[2])
            })
            reverse.adapter_sequence = ifelse(length(reverse.adapters)==0,"NA","Singleton")
            forward.adapter_sequence = ifelse(any(is.infinite(forward.dist)),"Wrong direction",ifelse(all(forward.dist==1),"Successive","Jump"))
            suffix = paste(forward.adapter_sequence,reverse.adapter_sequence,sep = "-")
            suffix = order_suffix(suffix)
        }else{
            forward.adapters = data.frame(from = forward.adapters[1:(length(forward.adapters)-1)],
                                  to = forward.adapters[2:length(forward.adapters)])
            forward.dist = apply(forward.adapters,1,function(forward.adapter){
                test_paths(adapters_graph,forward.adapter[1],forward.adapter[2])
            })

            reverse.adapters = data.frame(from = reverse.adapters[1:(length(reverse.adapters)-1)],
                                      to = reverse.adapters[2:length(reverse.adapters)])
            reverse.dist = apply(reverse.adapters,1,function(reverse.adapter){
                test_paths(adapters_graph,reverse.adapter[1],reverse.adapter[2])
            })
            forward.adapter_sequence = ifelse(any(is.infinite(forward.dist)),"Wrong direction",ifelse(all(forward.dist==1),"Successive","Jump"))
            reverse.adapter_sequence = ifelse(any(is.infinite(reverse.dist)),"Wrong direction",ifelse(all(reverse.dist==1),"Successive","Jump"))
            suffix = paste(forward.adapter_sequence,reverse.adapter_sequence,sep = "-")
            suffix = order_suffix(suffix)
        }
        final = paste(rc_mix,suffix,sep = ";")
    }else{
        final = "Singleton"
    }
}

test_paths <- function(g, from, to){
    ifelse(is.finite(c(shortest.paths(g, from,to,mode = "out"))),c(shortest.paths(g, from,  to,mode = "out")),Inf)
}

adapters = c(paste("adapter",LETTERS[1:16],sep  = ""),paste("adapter",LETTERS[1:16],".rc",sep  = ""))

links = data.frame(from = adapters[1:15],to = adapters[2:16])

links2 = data.frame(from = adapters[18:32],to = adapters[17:31])

links = rbind(links,links2)

adapter_graph = graph_from_data_frame(links,directed = T)

# %%
a = adapter_num(tsv[1:1000,])
# Out:
# Error in `$<-`:
# ! Assigned data `unlist(mclapply(df2$adapter_chain, classify_read,
#   mc.cores = 80))` must be compatible with existing data.
# ✖ Existing data has 286 rows.
# ✖ Assigned data has 480 rows.
# ℹ Only vectors of size 1 are recycled.
# Caused by error in `vectbl_recycle_rhs_rows()`:
# ! Can't recycle input of size 480 to size 286.
# Traceback:
#
# 1. adapter_num(tsv[1:1000, ])
# 2. `$<-`(`*tmp*`, classification, value = c("RC-successive;Jump",
#  . "RC-successive;Singleton", "No-RC;NA", "No-RC;Successive", "RC-mosaic;Jump",
#  . "RC-mosaic;Singleton", "Singleton", "RC-successive;Jump", "RC-successive;Successive",
#  . "RC-successive;Singleton", "RC-successive;Successive", "RC-successive;Jump",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "Singleton",
#  . "Singleton", "RC-successive;Singleton", "RC-successive;Successive",
#  . "No-RC;Jump", "No-RC;NA", "No-RC;NA", "No-RC;Successive", "No-RC;NA",
#  . "No-RC;Successive", "Singleton", "Singleton", "No-RC;Jump", "No-RC;NA",
#  . "RC-successive;Singleton", "RC-successive;Successive", "No-RC;NA",
#  . "No-RC;Successive", "No-RC;Jump", "No-RC;NA", "Singleton", "RC-mosaic;Singleton",
#  . "RC-mosaic;Wrong direction", "RC-successive;Successive", "RC-successive;Successive",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "RC-successive;Jump", "RC-successive;Successive", "Singleton",
#  . "No-RC;Jump", "No-RC;NA", "No-RC;Jump", "No-RC;NA", "RC-mosaic;Successive",
#  . "RC-mosaic;Wrong direction", "Singleton", "RC-successive;Jump",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "No-RC;NA",
#  . "No-RC;Successive", "Singleton", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;Jump", "No-RC;NA", "RC-successive;Successive", "RC-successive;Successive",
#  . "Singleton", "No-RC;Jump", "No-RC;NA", "RC-successive;Singleton",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Successive",
#  . "Singleton", "Singleton", "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton",
#  . "RC-successive;Successive", "Singleton", "RC-successive;Singleton-Singleton",
#  . "RC-successive;Jump", "RC-successive;Successive", "No-RC;NA",
#  . "No-RC;Successive", "No-RC;NA", "No-RC;Successive", "No-RC;NA",
#  . "No-RC;Successive", "RC-mosaic;Singleton", "RC-mosaic;Wrong direction",
#  . "RC-successive;Singleton-Singleton", "No-RC;Jump", "No-RC;NA",
#  . "No-RC;Jump", "No-RC;NA", "RC-successive;Jump", "RC-successive;Singleton",
#  . "Singleton", "RC-successive;Singleton-Singleton", "RC-mosaic;Successive",
#  . "RC-mosaic;Wrong direction", "No-RC;NA", "No-RC;Successive",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "Singleton", "Singleton",
#  . "RC-successive;Singleton-Singleton", "RC-successive;Successive",
#  . "RC-successive;Wrong direction", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Singleton-Singleton", "No-RC;NA", "No-RC;Successive",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Jump", "RC-successive;Successive", "RC-successive;Singleton-Singleton",
#  . "RC-successive;Singleton-Singleton", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Singleton", "RC-successive;Successive", "Singleton",
#  . "RC-successive;Singleton-Singleton", "RC-successive;Jump", "RC-successive;Jump",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "Singleton", "RC-successive;Singleton",
#  . "RC-successive;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;Jump", "No-RC;NA", "No-RC;NA",
#  . "No-RC;Successive", "RC-successive;Singleton-Singleton", "No-RC;NA",
#  . "No-RC;Successive", "RC-successive;Successive", "RC-successive;Successive",
#  . "No-RC;NA", "No-RC;Successive", "Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "RC-mosaic;Jump",
#  . "RC-mosaic;Wrong direction", "Singleton", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Successive", "RC-successive;Wrong direction",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "RC-successive;Successive",
#  . "RC-successive;Successive", "No-RC;Jump", "No-RC;NA", "Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;Jump", "No-RC;NA", "No-RC;NA",
#  . "No-RC;Successive", "RC-mosaic;Successive", "RC-mosaic;Successive",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Singleton", "RC-successive;Wrong direction", "RC-successive;Jump",
#  . "RC-successive;Wrong direction", "Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "RC-mosaic;Jump", "RC-mosaic;Wrong direction",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "No-RC;Jump",
#  . "No-RC;NA", "Singleton", "Singleton", "Singleton", "Singleton",
#  . "RC-mosaic;Jump", "RC-mosaic;Successive", "Singleton", "No-RC;NA",
#  . "No-RC;Successive", "Singleton", "RC-successive;Singleton", "RC-successive;Successive",
#  . "Singleton", "RC-successive;Jump", "RC-successive;Successive",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton", "RC-successive;Successive",
#  . "RC-successive;Singleton-Singleton", "No-RC;Jump", "No-RC;NA",
#  . "No-RC;NA", "No-RC;Successive", "Singleton", "RC-successive;Singleton-Singleton",
#  . "Singleton", "No-RC;Jump", "No-RC;NA", "No-RC;Jump", "No-RC;NA",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Singleton",
#  . "RC-successive;Successive", "Singleton", "RC-successive;Singleton",
#  . "RC-successive;Successive", "RC-successive;Singleton-Singleton",
#  . "RC-mosaic;Successive", "RC-mosaic;Wrong direction", "RC-mosaic;Jump",
#  . "RC-mosaic;Singleton", "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton",
#  . "RC-successive;Successive", "RC-successive;Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Wrong direction",
#  . "RC-successive;Singleton", "RC-successive;Successive", "No-RC;NA",
#  . "No-RC;Successive", "Singleton", "RC-successive;Singleton", "RC-successive;Successive",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;Jump", "No-RC;NA", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;NA", "No-RC;Wrong direction", "Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "Singleton",
#  . "No-RC;NA", "No-RC;Successive", "RC-mosaic;Successive", "RC-mosaic;Wrong direction",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "RC-successive;Singleton", "RC-successive;Successive", "Singleton",
#  . "Singleton", "RC-successive;Jump", "RC-successive;Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;Jump", "No-RC;NA", "Singleton",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "Singleton", "RC-mosaic;Jump", "RC-mosaic;Successive", "RC-successive;Singleton",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "RC-successive;Jump",
#  . "RC-successive;Successive", "Singleton", "Singleton", "Singleton",
#  . "RC-successive;Jump", "RC-successive;Singleton", "RC-mosaic;Successive",
#  . "RC-mosaic;Wrong direction", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Jump", "RC-successive;Successive", "Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;Jump", "No-RC;NA", "No-RC;NA", "No-RC;Successive", "No-RC;NA",
#  . "No-RC;Successive", "No-RC;NA", "No-RC;Successive", "Singleton",
#  . "No-RC;NA", "No-RC;Successive", "RC-mosaic;Successive", "RC-mosaic;Wrong direction",
#  . "RC-successive;Successive", "RC-successive;Wrong direction",
#  . "Singleton", "RC-successive;Successive", "RC-successive;Successive",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;Jump", "No-RC;NA", "No-RC;NA", "No-RC;Successive", "No-RC;NA",
#  . "No-RC;Successive", "RC-successive;Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "Singleton", "RC-successive;Singleton",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "Singleton",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "No-RC;Jump", "No-RC;NA",
#  . "RC-mosaic;Wrong direction", "RC-mosaic;Wrong direction", "No-RC;Jump",
#  . "No-RC;NA", "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "Singleton", "RC-successive;Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "RC-successive;Wrong direction",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Successive",
#  . "RC-successive;Wrong direction", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;NA", "No-RC;Successive", "Singleton", "Singleton", "Singleton",
#  . "RC-successive;Jump", "RC-successive;Successive", "No-RC;NA",
#  . "No-RC;Successive", "RC-successive;Jump", "RC-successive;Singleton",
#  . "Singleton", "RC-successive;Singleton-Singleton", "No-RC;NA",
#  . "No-RC;Successive", "Singleton", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;Jump", "No-RC;NA", "RC-successive;Successive", "RC-successive;Successive",
#  . "RC-successive;Singleton-Singleton", "RC-mosaic;Jump", "RC-mosaic;Singleton",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Successive",
#  . "RC-successive;Successive", "RC-successive;Jump", "RC-successive;Jump",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Wrong direction",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "Singleton", "No-RC;NA",
#  . "No-RC;Successive", "No-RC;NA", "No-RC;Successive", "Singleton",
#  . "RC-successive;Singleton", "RC-successive;Successive", "No-RC;NA",
#  . "No-RC;Successive"))   # at line 21 of file <text>
# 3. `$<-.tbl_df`(`*tmp*`, classification, value = c("RC-successive;Jump",
#  . "RC-successive;Singleton", "No-RC;NA", "No-RC;Successive", "RC-mosaic;Jump",
#  . "RC-mosaic;Singleton", "Singleton", "RC-successive;Jump", "RC-successive;Successive",
#  . "RC-successive;Singleton", "RC-successive;Successive", "RC-successive;Jump",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "Singleton",
#  . "Singleton", "RC-successive;Singleton", "RC-successive;Successive",
#  . "No-RC;Jump", "No-RC;NA", "No-RC;NA", "No-RC;Successive", "No-RC;NA",
#  . "No-RC;Successive", "Singleton", "Singleton", "No-RC;Jump", "No-RC;NA",
#  . "RC-successive;Singleton", "RC-successive;Successive", "No-RC;NA",
#  . "No-RC;Successive", "No-RC;Jump", "No-RC;NA", "Singleton", "RC-mosaic;Singleton",
#  . "RC-mosaic;Wrong direction", "RC-successive;Successive", "RC-successive;Successive",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "RC-successive;Jump", "RC-successive;Successive", "Singleton",
#  . "No-RC;Jump", "No-RC;NA", "No-RC;Jump", "No-RC;NA", "RC-mosaic;Successive",
#  . "RC-mosaic;Wrong direction", "Singleton", "RC-successive;Jump",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "No-RC;NA",
#  . "No-RC;Successive", "Singleton", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;Jump", "No-RC;NA", "RC-successive;Successive", "RC-successive;Successive",
#  . "Singleton", "No-RC;Jump", "No-RC;NA", "RC-successive;Singleton",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Successive",
#  . "Singleton", "Singleton", "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton",
#  . "RC-successive;Successive", "Singleton", "RC-successive;Singleton-Singleton",
#  . "RC-successive;Jump", "RC-successive;Successive", "No-RC;NA",
#  . "No-RC;Successive", "No-RC;NA", "No-RC;Successive", "No-RC;NA",
#  . "No-RC;Successive", "RC-mosaic;Singleton", "RC-mosaic;Wrong direction",
#  . "RC-successive;Singleton-Singleton", "No-RC;Jump", "No-RC;NA",
#  . "No-RC;Jump", "No-RC;NA", "RC-successive;Jump", "RC-successive;Singleton",
#  . "Singleton", "RC-successive;Singleton-Singleton", "RC-mosaic;Successive",
#  . "RC-mosaic;Wrong direction", "No-RC;NA", "No-RC;Successive",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "Singleton", "Singleton",
#  . "RC-successive;Singleton-Singleton", "RC-successive;Successive",
#  . "RC-successive;Wrong direction", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Singleton-Singleton", "No-RC;NA", "No-RC;Successive",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Jump", "RC-successive;Successive", "RC-successive;Singleton-Singleton",
#  . "RC-successive;Singleton-Singleton", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Singleton", "RC-successive;Successive", "Singleton",
#  . "RC-successive;Singleton-Singleton", "RC-successive;Jump", "RC-successive;Jump",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "Singleton", "RC-successive;Singleton",
#  . "RC-successive;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;Jump", "No-RC;NA", "No-RC;NA",
#  . "No-RC;Successive", "RC-successive;Singleton-Singleton", "No-RC;NA",
#  . "No-RC;Successive", "RC-successive;Successive", "RC-successive;Successive",
#  . "No-RC;NA", "No-RC;Successive", "Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "RC-mosaic;Jump",
#  . "RC-mosaic;Wrong direction", "Singleton", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Successive", "RC-successive;Wrong direction",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "RC-successive;Successive",
#  . "RC-successive;Successive", "No-RC;Jump", "No-RC;NA", "Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;Jump", "No-RC;NA", "No-RC;NA",
#  . "No-RC;Successive", "RC-mosaic;Successive", "RC-mosaic;Successive",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Singleton", "RC-successive;Wrong direction", "RC-successive;Jump",
#  . "RC-successive;Wrong direction", "Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "RC-mosaic;Jump", "RC-mosaic;Wrong direction",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "No-RC;Jump",
#  . "No-RC;NA", "Singleton", "Singleton", "Singleton", "Singleton",
#  . "RC-mosaic;Jump", "RC-mosaic;Successive", "Singleton", "No-RC;NA",
#  . "No-RC;Successive", "Singleton", "RC-successive;Singleton", "RC-successive;Successive",
#  . "Singleton", "RC-successive;Jump", "RC-successive;Successive",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton", "RC-successive;Successive",
#  . "RC-successive;Singleton-Singleton", "No-RC;Jump", "No-RC;NA",
#  . "No-RC;NA", "No-RC;Successive", "Singleton", "RC-successive;Singleton-Singleton",
#  . "Singleton", "No-RC;Jump", "No-RC;NA", "No-RC;Jump", "No-RC;NA",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Singleton",
#  . "RC-successive;Successive", "Singleton", "RC-successive;Singleton",
#  . "RC-successive;Successive", "RC-successive;Singleton-Singleton",
#  . "RC-mosaic;Successive", "RC-mosaic;Wrong direction", "RC-mosaic;Jump",
#  . "RC-mosaic;Singleton", "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton",
#  . "RC-successive;Successive", "RC-successive;Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Wrong direction",
#  . "RC-successive;Singleton", "RC-successive;Successive", "No-RC;NA",
#  . "No-RC;Successive", "Singleton", "RC-successive;Singleton", "RC-successive;Successive",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;Jump", "No-RC;NA", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;NA", "No-RC;Wrong direction", "Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "Singleton",
#  . "No-RC;NA", "No-RC;Successive", "RC-mosaic;Successive", "RC-mosaic;Wrong direction",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "RC-successive;Singleton", "RC-successive;Successive", "Singleton",
#  . "Singleton", "RC-successive;Jump", "RC-successive;Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;Jump", "No-RC;NA", "Singleton",
#  . "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "Singleton", "RC-mosaic;Jump", "RC-mosaic;Successive", "RC-successive;Singleton",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "RC-successive;Jump",
#  . "RC-successive;Successive", "Singleton", "Singleton", "Singleton",
#  . "RC-successive;Jump", "RC-successive;Singleton", "RC-mosaic;Successive",
#  . "RC-mosaic;Wrong direction", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "RC-successive;Jump", "RC-successive;Successive", "Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;Jump", "No-RC;NA", "No-RC;NA", "No-RC;Successive", "No-RC;NA",
#  . "No-RC;Successive", "No-RC;NA", "No-RC;Successive", "Singleton",
#  . "No-RC;NA", "No-RC;Successive", "RC-mosaic;Successive", "RC-mosaic;Wrong direction",
#  . "RC-successive;Successive", "RC-successive;Wrong direction",
#  . "Singleton", "RC-successive;Successive", "RC-successive;Successive",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;Jump", "No-RC;NA", "No-RC;NA", "No-RC;Successive", "No-RC;NA",
#  . "No-RC;Successive", "RC-successive;Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Singleton-Singleton",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Successive",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "Singleton", "RC-successive;Singleton",
#  . "RC-successive;Successive", "No-RC;NA", "No-RC;Successive", "Singleton",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "No-RC;Jump", "No-RC;NA",
#  . "RC-mosaic;Wrong direction", "RC-mosaic;Wrong direction", "No-RC;Jump",
#  . "No-RC;NA", "No-RC;NA", "No-RC;Successive", "RC-successive;Singleton-Singleton",
#  . "Singleton", "RC-successive;Singleton", "RC-successive;Successive",
#  . "RC-successive;Successive", "RC-successive;Wrong direction",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Successive",
#  . "RC-successive;Wrong direction", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;NA", "No-RC;Successive", "Singleton", "Singleton", "Singleton",
#  . "RC-successive;Jump", "RC-successive;Successive", "No-RC;NA",
#  . "No-RC;Successive", "RC-successive;Jump", "RC-successive;Singleton",
#  . "Singleton", "RC-successive;Singleton-Singleton", "No-RC;NA",
#  . "No-RC;Successive", "Singleton", "No-RC;NA", "No-RC;Successive",
#  . "No-RC;Jump", "No-RC;NA", "RC-successive;Successive", "RC-successive;Successive",
#  . "RC-successive;Singleton-Singleton", "RC-mosaic;Jump", "RC-mosaic;Singleton",
#  . "RC-successive;Successive", "RC-successive;Successive", "RC-successive;Successive",
#  . "RC-successive;Successive", "RC-successive;Jump", "RC-successive;Jump",
#  . "No-RC;NA", "No-RC;Successive", "No-RC;NA", "No-RC;Wrong direction",
#  . "Singleton", "No-RC;NA", "No-RC;Successive", "Singleton", "No-RC;NA",
#  . "No-RC;Successive", "No-RC;NA", "No-RC;Successive", "Singleton",
#  . "RC-successive;Singleton", "RC-successive;Successive", "No-RC;NA",
#  . "No-RC;Successive"))   # at line 21 of file <text>
# 4. tbl_subassign(x, i = NULL, as_string(name), list(value), i_arg = NULL,
#  .     j_arg = name, value_arg = substitute(value))
# 5. vectbl_recycle_rhs_rows(value, fast_nrow(xo), i_arg = NULL, value_arg,
#  .     call)
# 6. withCallingHandlers(for (j in seq_along(value)) {
#  .     if (!is.null(value[[j]])) {
#  .         value[[j]] <- vec_recycle(value[[j]], nrow)
#  .     }
#  . }, vctrs_error_recycle_incompatible_size = function(cnd) {
#  .     abort_assign_incompatible_size(nrow, value, j, i_arg, value_arg,
#  .         cnd, call = call)
#  . }, vctrs_error_scalar_type = function(cnd) {
#  .     abort_assign_vector(value, j, value_arg, cnd, call = call)
#  . })
# 7. vec_recycle(value[[j]], nrow)
# 8. stop_recycle_incompatible_size(x_size = 480L, size = 286L, x_arg = "",
#  .     call = <environment>)
# 9. stop_vctrs(x_size = x_size, y_size = size, x_arg = x_arg, class = c("vctrs_error_incompatible_size",
#  .     "vctrs_error_recycle_incompatible_size"), call = call)
# 10. abort(message, class = c(class, "vctrs_error"), ..., call = call)
# 11. signal_abort(cnd, .file)
# 12. signalCondition(cnd)
# 13. (function (cnd)
#   . {
#   .     abort_assign_incompatible_size(nrow, value, j, i_arg, value_arg,
#   .         cnd, call = call)
#   . })(structure(list(message = "", trace = structure(list(call = list(
#   .     IRkernel::main(), kernel$run(), handle_shell(), executor$execute(msg),
#   .     tryCatch(evaluate(request$content$code, envir = .GlobalEnv,
#   .         output_handler = oh, stop_on_error = 1L), interrupt = function(cond) {
#   .         log_debug("Interrupt during execution")
#   .         interrupted <<- TRUE
#   .     }, error = .self$handle_error), tryCatchList(expr, classes,
#   .         parentenv, handlers), tryCatchOne(tryCatchList(expr,
#   .         names[-nh], parentenv, handlers[-nh]), names[nh], parentenv,
#   .         handlers[[nh]]), doTryCatch(return(expr), name, parentenv,
#   .         handler), tryCatchList(expr, names[-nh], parentenv, handlers[-nh]),
#   .     tryCatchOne(expr, names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), evaluate(request$content$code,
#   .         envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .     evaluate_call(expr, parsed$src[[i]], envir = envir, enclos = enclos,
#   .         debug = debug, last = i == length(out), use_try = stop_on_error !=
#   .             2L, keep_warning = keep_warning, keep_message = keep_message,
#   .         output_handler = output_handler, include_timing = include_timing),
#   .     timing_fn(handle(ev <- withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler))), handle(ev <- withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler)), try(f, silent = TRUE), tryCatch(expr,
#   .         error = function(e) {
#   .             call <- conditionCall(e)
#   .             if (!is.null(call)) {
#   .                 if (identical(call[[1L]], quote(doTryCatch)))
#   .                   call <- sys.call(-4L)
#   .                 dcall <- deparse(call, nlines = 1L)
#   .                 prefix <- paste("Error in", dcall, ": ")
#   .                 LONG <- 75L
#   .                 sm <- strsplit(conditionMessage(e), "\n")[[1L]]
#   .                 w <- 14L + nchar(dcall, type = "w") + nchar(sm[1L],
#   .                   type = "w")
#   .                 if (is.na(w))
#   .                   w <- 14L + nchar(dcall, type = "b") + nchar(sm[1L],
#   .                     type = "b")
#   .                 if (w > LONG)
#   .                   prefix <- paste0(prefix, "\n  ")
#   .             }
#   .             else prefix <- "Error : "
#   .             msg <- paste0(prefix, conditionMessage(e), "\n")
#   .             .Internal(seterrmessage(msg[1L]))
#   .             if (!silent && isTRUE(getOption("show.error.messages"))) {
#   .                 cat(msg, file = outFile)
#   .                 .Internal(printDeferredWarnings())
#   .             }
#   .             invisible(structure(msg, class = "try-error", condition = e))
#   .         }), tryCatchList(expr, classes, parentenv, handlers),
#   .     tryCatchOne(expr, names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler), withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers), eval(expr, envir, enclos),
#   .     eval(expr, envir, enclos), adapter_num(tsv[1:1000, ]), `$<-`(`*tmp*`,
#   .         classification, value = `<chr>`), `$<-.tbl_df`(`*tmp*`,
#   .         classification, value = `<chr>`), tbl_subassign(x, i = NULL,
#   .         as_string(name), list(value), i_arg = NULL, j_arg = name,
#   .         value_arg = substitute(value)), vectbl_recycle_rhs_rows(value,
#   .         fast_nrow(xo), i_arg = NULL, value_arg, call), withCallingHandlers(for (j in seq_along(value)) {
#   .         if (!is.null(value[[j]])) {
#   .             value[[j]] <- vec_recycle(value[[j]], nrow)
#   .         }
#   .     }, vctrs_error_recycle_incompatible_size = function(cnd) {
#   .         abort_assign_incompatible_size(nrow, value, j, i_arg,
#   .             value_arg, cnd, call = call)
#   .     }, vctrs_error_scalar_type = function(cnd) {
#   .         abort_assign_vector(value, j, value_arg, cnd, call = call)
#   .     }), vec_recycle(value[[j]], nrow), stop_recycle_incompatible_size(x_size = 480L,
#   .         size = 286L, x_arg = "", call = `<env>`), stop_vctrs(x_size = x_size,
#   .         y_size = size, x_arg = x_arg, class = c("vctrs_error_incompatible_size",
#   .             "vctrs_error_recycle_incompatible_size"), call = call),
#   .     abort(message, class = c(class, "vctrs_error"), ..., call = call)),
#   .     parent = c(0L, 1L, 2L, 3L, 4L, 5L, 6L, 7L, 6L, 9L, 10L, 4L,
#   .     12L, 13L, 13L, 15L, 16L, 17L, 18L, 19L, 13L, 13L, 13L, 23L,
#   .     24L, 0L, 26L, 26L, 28L, 29L, 30L, 30L, 0L, 33L, 34L), visible = c(TRUE,
#   .     TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .     TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .     TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, FALSE,
#   .     FALSE, FALSE, FALSE, FALSE), namespace = c("IRkernel", NA,
#   .     "IRkernel", NA, "base", "base", "base", "base", "base", "base",
#   .     "base", "evaluate", "evaluate", "evaluate", "evaluate", "base",
#   .     "base", "base", "base", "base", "base", "base", "evaluate",
#   .     "base", "base", NA, "base", "tibble", "tibble", "tibble",
#   .     "base", "vctrs", "vctrs", "vctrs", "rlang"), scope = c("::",
#   .     NA, "local", NA, "::", "local", "local", "local", "local",
#   .     "local", "local", "::", ":::", "local", "local", "::", "::",
#   .     "local", "local", "local", "::", "::", ":::", "::", "::",
#   .     "global", "::", ":::", ":::", ":::", "::", "::", ":::", ":::",
#   .     "::"), error_frame = c(FALSE, FALSE, FALSE, FALSE, FALSE,
#   .     FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .     FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .     FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, TRUE, FALSE, FALSE,
#   .     FALSE, FALSE, FALSE)), row.names = c(NA, -35L), version = 2L, class = c("rlang_trace",
#   . "rlib_trace", "tbl", "data.frame")), parent = NULL, x_size = 480L,
#   .     y_size = 286L, x_arg = "", rlang = list(inherit = TRUE),
#   .     call = vectbl_recycle_rhs_rows(value, fast_nrow(xo), i_arg = NULL,
#   .         value_arg, call)), class = c("vctrs_error_incompatible_size",
#   . "vctrs_error_recycle_incompatible_size", "vctrs_error", "rlang_error",
#   . "error", "condition")))
# 14. abort_assign_incompatible_size(nrow, value, j, i_arg, value_arg,
#   .     cnd, call = call)
# 15. tibble_abort(bullets(paste0("Assigned data ", tick(as_label(value_arg)),
#   .     " must be compatible with ", target, ":"), x = existing,
#   .     x = new, i = if (nrow != 1) "Only vectors of size 1 are recycled",
#   .     i = if (nrow == 1 && vec_size(value[[j]]) != 1) "Row updates require a list value. Do you need `list()` or `as.list()`?"),
#   .     expected = nrow, actual = vec_size(value[[j]]), j = j, parent = parent,
#   .     call = call)
# 16. abort(x, class, ..., call = call, parent = parent, use_cli_format = TRUE)
# 17. signal_abort(cnd, .file)

# %%
a
# Out:
#     fqname
# 1   000000d6-25b9-433a-be9f-a47958002048
# 2   000001c0-e4f8-487c-86ec-c1fb54d55a4e
# 3   000018d2-cd68-4109-82db-726ea92c1fdf
# 4   00002219-6961-4207-afbf-2db56725b61c
# 5   000026b5-ecb4-44d0-8a24-f36231839d63
# 6   00002c26-5eea-48d9-871f-232d34632482
# 7   00002e4b-c436-4437-84d5-dd0c0fc6ee5c
# 8   00003b02-a74f-4a45-8db0-5cdab3dd780f
# 9   00004cf3-2404-4994-add6-213b35a215c0
# 10  00004ecb-4c51-4111-8b7b-b231e51d67e8
# 11  00005178-78f2-4652-b0e4-cc6999ce2b68
# 12  00005c1c-b4b4-49a3-8f6b-60c962893dcf
# 13  000066f8-9538-4c57-8c5d-881199bd49f8
# 14  0000678d-aef3-449c-8efb-60d76ab19f4a
# 15  000067db-2c73-4556-920a-57f8fdc20f5b
# 16  00008641-9990-49d4-8218-0be9db384fdd
# 17  00008d08-bb4f-4d01-bb29-89b721be356f
# 18  00009482-02ee-4287-b296-132cae1cd259
# 19  000094f0-bfea-4c3d-bdd3-80bdff5b7e93
# 20  0000a5c8-7107-40f0-9735-1666cb1b8de6
# 21  0000a794-351a-4294-9db3-c141482cfbca
# 22  0000aa96-956a-49dc-9a39-bbf52932bec9
# 23  0000b227-e209-4f2c-aacf-a79480149681
# 24  0000b76f-0117-4068-92ec-5ec1d01c93b9
# 25  0000c1e5-674c-466b-9ab9-cc7e8f1eed10
# 26  0000c363-8134-47b7-ab64-79e05eace458
# 27  0000cf3b-ec3c-4134-b413-b3e3fb31aeed
# 28  0000cf3f-8ed3-4ac4-b450-1bd7fb643fdb
# 29  0000d50d-e456-455e-8342-0ef237860f23
# 30  0000d8d9-bdbb-4a5a-97a8-35742acfbf34
# ⋮   ⋮
# 257 0007d59d-c248-4087-9de6-3e1f6322e562
# 258 0007e3f0-e229-4a2e-80a6-265c22724491
# 259 0007e911-3f05-4d56-8e8a-ffdbd1e78ca5
# 260 0007ee08-b7a7-432a-8775-1873c64e898d
# 261 0008054a-8b23-4c90-81fc-ab984fbb10d8
# 262 000805b9-69a2-4d8f-bcb9-2adca44573eb
# 263 000817ce-7591-491c-8bd1-6990076cfd13
# 264 000818e5-3a7c-475b-bc1f-2e7092539707
# 265 00081cb3-dd94-420d-b7c5-e59b8fbf6f76
# 266 0008251c-004e-4f41-83d0-6f3e1b96e0e6
# 267 00082e95-ce4a-4dad-94a1-4ebb463840fb
# 268 00083072-d986-4b2b-adc6-6ae4e5125596
# 269 000832c5-6295-429a-9564-22ffb6e4ef65
# 270 00083c2f-2efc-4ce2-9785-ff7bfc0b5185
# 271 00083cc9-9c99-426c-b80f-54c620a7b48f
# 272 0008451e-be3b-4818-a20d-a63399887923
# 273 000846dd-5953-4dcd-99fe-f91a31a03343
# 274 000848ac-d96e-4563-b9b5-3724efea8d34
# 275 000850d9-03f5-4793-92db-a198487e4bc4
# 276 00085a6d-6178-4aff-a994-a57a6121e937
# 277 000866d9-989e-4226-bae4-81e913b4cb85
# 278 00087e54-fc2d-4b2c-ad5d-f1edc96aeb20
# 279 00087fcb-9e56-4f2d-8b02-cd5c74efd0d3
# 280 00087ffb-840b-4ccd-a9ab-1be579a20c30
# 281 00089222-2f7b-4a21-bbaf-95dbe88152b9
# 282 00089f0b-d9bf-4c4f-969a-aa0275dcf0d0
# 283 0008b082-4e20-487e-bc7d-5c49782420ef
# 284 0008ba0c-19cc-4b53-ad5c-88c83a77762f
# 285 0008e20c-3938-4706-8c57-d053ef5f9a5f
# 286 0008e51f-f50e-4aa5-aba5-f385f6dfa29c
#     adapter_chain
# 1   adapterC,adapterD,adapterE,adapterF,adapterG,adapterJ,adapterJ.rc
# 2   adapterP.rc,adapterO.rc,adapterN.rc
# 3   adapterA,adapterB,adapterC,adapterD.rc,adapterD,adapterF,adapterG,adapterH
# 4   adapterN.rc
# 5   adapterD,adapterE,adapterF,adapterG.rc,adapterF.rc,adapterE.rc,adapterD.rc,adapterD.rc,adapterC.rc
# 6   adapterA,adapterB,adapterC,adapterD,adapterD.rc
# 7   adapterL,adapterM,adapterN,adapterO,adapterO.rc,adapterN.rc,adapterM.rc,adapterL.rc,adapterK.rc,adapterJ.rc,adapterH.rc
# 8   adapterH.rc,adapterG.rc
# 9   adapterP
# 10  adapterA.rc
# 11  adapterH,adapterH.rc,adapterG.rc,adapterF.rc,adapterE.rc
# 12  adapterP.rc,adapterO.rc,adapterN.rc,adapterM.rc,adapterL.rc,adapterK.rc,adapterI.rc,adapterH.rc
# 13  adapterP.rc,adapterO.rc,adapterN.rc,adapterM.rc
# 14  adapterP.rc,adapterO.rc
# 15  adapterP.rc
# 16  adapterB
# 17  adapterA,adapterB,adapterC,adapterE,adapterF,adapterG,adapterH
# 18  adapterB,adapterB.rc,adapterA.rc
# 19  adapterP.rc,adapterO.rc
# 20  adapterL,adapterO,adapterP
# 21  adapterB.rc
# 22  adapterD.rc,adapterG,adapterG.rc
# 23  adapterM,adapterN,adapterO,adapterO.rc,adapterN.rc
# 24  adapterP.rc,adapterO.rc,adapterN.rc
# 25  adapterB.rc,adapterA.rc
# 26  adapterI,adapterJ,adapterK,adapterL,adapterM,adapterN,adapterO
# 27  adapterP.rc,adapterP
# 28  adapterF,adapterG,adapterG.rc,adapterF.rc,adapterE.rc,adapterC.rc
# 29  adapterP.rc
# 30  adapterG.rc,adapterE.rc,adapterD.rc
# ⋮   ⋮
# 257 adapterP.rc,adapterO.rc
# 258 adapterM.rc,adapterL.rc
# 259 adapterN.rc
# 260 adapterA
# 261 adapterI
# 262 adapterP.rc,adapterO.rc,adapterN.rc,adapterM.rc,adapterE.rc,adapterN,adapterO,adapterP
# 263 adapterF.rc,adapterE.rc,adapterD.rc
# 264 adapterP.rc,adapterN,adapterP
# 265 adapterP.rc
# 266 adapterD,adapterE.rc
# 267 adapterA,adapterB,adapterC,adapterD,adapterE,adapterF,adapterG
# 268 adapterD.rc
# 269 adapterB,adapterC
# 270 adapterD,adapterM
# 271 adapterP.rc,adapterO.rc,adapterN.rc,adapterN,adapterO,adapterP
# 272 adapterA,adapterA.rc
# 273 adapterA,adapterB,adapterC,adapterC.rc,adapterD,adapterE,adapterG
# 274 adapterN,adapterO,adapterN.rc,adapterM.rc
# 275 adapterM,adapterN,adapterM.rc,adapterL.rc
# 276 adapterI,adapterJ,adapterL,adapterL.rc,adapterK.rc,adapterI.rc
# 277 adapterP.rc,adapterO.rc
# 278 adapterO.rc,adapterN.rc,adapterM.rc,adapterL.rc,adapterK.rc,adapterJ.rc,adapterI.rc,adapterH.rc,adapterG.rc,adapterF.rc,adapterD.rc,adapterE.rc
# 279 adapterN
# 280 adapterD,adapterE,adapterF,adapterG,adapterH
# 281 adapterF.rc
# 282 adapterP.rc,adapterO.rc,adapterN.rc,adapterM.rc,adapterL.rc
# 283 adapterP.rc,adapterO.rc
# 284 adapterA.rc
# 285 adapterC,adapterD,adapterD.rc
# 286 adapterP.rc,adapterO.rc
